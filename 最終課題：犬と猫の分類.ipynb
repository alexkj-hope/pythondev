# %%
import tensorflow as tf

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "dog_cat_photos/train",
    image_size=(224, 224),
    label_mode="binary",
    batch_size=32,
    shuffle=True
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "dog_cat_photos/test",
    image_size=(224, 224),
    label_mode="binary",
    batch_size=32,
    shuffle=False
)
# Out:
# Found 300 files belonging to 2 classes.
# Found 100 files belonging to 2 classes.

# %%
def flip_left_right(image, label):   # horizontal flip
    image = tf.image.flip_left_right(image)
    return image, label

def flip_up_down(image, label):      # vertical flip
    image = tf.image.flip_up_down(image)
    return image, label

def rot90(image, label):             # 90° CCW
    image = tf.image.rot90(image)
    return image, label

def rot180(image, label):            # 180° CCW
    image = tf.image.rot90(image, k=2)
    return image, label

def rot270(image, label):            # 270° CCW
    image = tf.image.rot90(image, k=3)
    return image, label

# %%
train_dataset_lr     = train_dataset.map(flip_left_right)
train_dataset_ud     = train_dataset.map(flip_up_down)
train_dataset_rot90  = train_dataset.map(rot90)
train_dataset_rot180 = train_dataset.map(rot180)
train_dataset_rot270 = train_dataset.map(rot270)

# %%
train_dataset = train_dataset.concatenate(train_dataset_lr)
train_dataset = train_dataset.concatenate(train_dataset_ud)
train_dataset = train_dataset.concatenate(train_dataset_rot90)
train_dataset = train_dataset.concatenate(train_dataset_rot180)
train_dataset = train_dataset.concatenate(train_dataset_rot270)

# %%
train_dataset = train_dataset.shuffle(32)

# %%
input_layer = tf.keras.Input(shape=(224, 224, 3))
preproc     = tf.keras.applications.mobilenet_v2.preprocess_input(input_layer)

base_model = tf.keras.applications.mobilenet_v2.MobileNetV2(
    input_shape=(224, 224, 3),
    input_tensor=preproc,
    include_top=False,
    weights="imagenet",
    pooling="avg"
)
base_model.trainable = False

# %%
output_layer = tf.keras.layers.Dense(1, activation="sigmoid")

# %%
model = tf.keras.Sequential([
    base_model,
    output_layer
])

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(train_dataset, epochs=20)
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 61s 891ms/step - accuracy: 0.6860 - loss: 0.5494
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 54s 879ms/step - accuracy: 0.9412 - loss: 0.1777
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 51s 835ms/step - accuracy: 0.9504 - loss: 0.1505
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 54s 901ms/step - accuracy: 0.9670 - loss: 0.1121
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 55s 896ms/step - accuracy: 0.9672 - loss: 0.0985
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 59s 960ms/step - accuracy: 0.9749 - loss: 0.0892
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9813 - loss: 0.0773
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9812 - loss: 0.0696
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9903 - loss: 0.0582
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 61s 992ms/step - accuracy: 0.9910 - loss: 0.0525
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 55s 876ms/step - accuracy: 0.9932 - loss: 0.0475
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 54s 875ms/step - accuracy: 0.9936 - loss: 0.0412
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 53s 864ms/step - accuracy: 0.9922 - loss: 0.0429
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 56s 908ms/step - accuracy: 0.9929 - loss: 0.0374
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 53s 863ms/step - accuracy: 0.9956 - loss: 0.0309
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 50s 817ms/step - accuracy: 0.9946 - loss: 0.0364
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 53s 863ms/step - accuracy: 0.9972 - loss: 0.0310
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 50s 812ms/step - accuracy: 0.9988 - loss: 0.0306
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 48s 792ms/step - accuracy: 0.9993 - loss: 0.0254
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 51s 838ms/step - accuracy: 0.9980 - loss: 0.0235

# %%
pred_data = model.predict(test_dataset)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step

# %%
pred_data
# Out:
# array([[5.3120595e-05],
#        [2.5200169e-04],
#        [1.5140719e-04],
#        [8.0897921e-04],
#        [1.0034416e-03],
#        [3.7586404e-04],
#        [1.4976728e-03],
#        [4.5441161e-04],
#        [8.1807275e-06],
#        [6.2793121e-04],
#        [5.6488345e-05],
#        [2.8902765e-03],
#        [4.1669584e-03],
#        [7.7922200e-04],
#        [7.0510046e-05],
#        [1.1554519e-05],
#        [2.3019596e-04],
#        [5.8869127e-04],
#        [8.4924512e-03],
#        [2.9042929e-03],
#        [4.0091695e-03],
#        [9.2440113e-02],
#        [5.4039755e-03],
#        [3.8921446e-04],
#        [1.2569073e-01],
#        [1.5233294e-03],
#        [9.0203696e-04],
#        [7.7137590e-04],
#        [5.9111505e-03],
#        [3.6121646e-04],
#        [3.7140475e-04],
#        [8.1487250e-01],
#        [2.3707903e-04],
#        [9.6408185e-04],
#        [7.4796076e-03],
#        [8.8862538e-01],
#        [6.0495944e-03],
#        [1.7866758e-03],
#        [4.7190607e-02],
#        [4.0700758e-04],
#        [3.8288167e-04],
#        [6.0451170e-04],
#        [4.6815947e-02],
#        [2.1821228e-04],
#        [7.4961863e-04],
#        [6.7683600e-02],
#        [6.0506706e-04],
#        [1.4237834e-03],
#        [4.1964073e-03],
#        [1.4044248e-04],
#        [9.9791163e-01],
#        [9.9984968e-01],
#        [9.9996763e-01],
#        [9.9965388e-01],
#        [9.9931598e-01],
#        [2.3288806e-01],
#        [9.9998933e-01],
#        [9.9996865e-01],
#        [9.9952352e-01],
#        [9.9985540e-01],
#        [9.9993527e-01],
#        [9.7914243e-01],
#        [9.3119907e-01],
#        [9.9887019e-01],
#        [9.9981308e-01],
#        [9.9905992e-01],
#        [9.9992824e-01],
#        [9.9994737e-01],
#        [9.9972671e-01],
#        [9.9839109e-01],
#        [9.7766125e-01],
#        [9.9824297e-01],
#        [9.9991673e-01],
#        [9.9537450e-01],
#        [9.9985033e-01],
#        [9.9999255e-01],
#        [9.9998689e-01],
#        [9.9997836e-01],
#        [9.9995291e-01],
#        [4.1994524e-01],
#        [9.9952954e-01],
#        [9.8864561e-01],
#        [9.9761087e-01],
#        [9.9260676e-01],
#        [9.9998796e-01],
#        [9.9844813e-01],
#        [9.9999487e-01],
#        [9.9995512e-01],
#        [9.9999624e-01],
#        [9.9965346e-01],
#        [9.9990398e-01],
#        [9.9965215e-01],
#        [9.9975204e-01],
#        [9.9955273e-01],
#        [9.9999917e-01],
#        [9.9718994e-01],
#        [9.9992353e-01],
#        [9.9998659e-01],
#        [9.9979478e-01],
#        [9.7411692e-01]], dtype=float32)

# %%
model.evaluate(test_dataset)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 631ms/step - accuracy: 0.9600 - loss: 0.0724
# [0.06858659535646439, 0.9599999785423279]
